# %%
from IPython.display import Image
import os, sys
pathToDir = "/afs/cern.ch/work/v/vkhriste/Projects/HiggsAnalysis/analysis_results/backgroundfitswithroomultipdf/vR1_20170412_2336"

# %%
Image(filename=os.path.join(pathToDir,'backgroundFits__01JetsTightBB__modelGroupTest.png'))
