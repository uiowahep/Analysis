# %%
from IPython.display import Image
import os, sys
pathToDir = "/afs/cern.ch/work/v/vkhriste/Projects/HiggsAnalysis/analysis_results/signalfitinterpolationswithspline/vR1_20170412_2336"

# %% [markdown]
# # Setup
#
# - __0.25 GeV Binning__
# - __01JetsTightBB Category__
# - __Recursive Fractions!!!__

# %% [markdown]
# # SingleGaus

# %%
Image(filename=os.path.join(pathToDir,'signalFitInterpolationWithSpline__01JetsTightBB__GluGlu__SingleGaus__.png'))

# %%
Image(filename=os.path.join(pathToDir,'signalFit__01JetsTightBB__120__GluGlu__SingleGaus__default.png'))

# %%
Image(filename=os.path.join(pathToDir,'signalFit__01JetsTightBB__125__GluGlu__SingleGaus__default.png'))

# %%
Image(filename=os.path.join(pathToDir,'signalFit__01JetsTightBB__130__GluGlu__SingleGaus__default.png'))

# %% [markdown]
# # Double Gaus

# %%
Image(filename=os.path.join(pathToDir,'signalFitInterpolationWithSpline__01JetsTightBB__GluGlu__DoubleGaus__.png'))

# %%
Image(filename=os.path.join(pathToDir,'signalFit__01JetsTightBB__120__GluGlu__DoubleGaus__default.png'))

# %%
Image(filename=os.path.join(pathToDir,'signalFit__01JetsTightBB__125__GluGlu__DoubleGaus__default.png'))

# %%
Image(filename=os.path.join(pathToDir,'signalFit__01JetsTightBB__130__GluGlu__DoubleGaus__default.png'))

# %%
Image(filename=os.path.join(pathToDir,'signalFitInterpolationWithSpline__01JetsTightBB__GluGlu__TripleGaus__.png'))

# %%
Image(filename=os.path.join(pathToDir,'signalFit__01JetsTightBB__120__GluGlu__TripleGaus__default.png'))

# %%
Image(filename=os.path.join(pathToDir,'signalFit__01JetsTightBB__125__GluGlu__TripleGaus__default.png'))

# %%
Image(filename=os.path.join(pathToDir,'signalFit__01JetsTightBB__130__GluGlu__TripleGaus__default.png'))
