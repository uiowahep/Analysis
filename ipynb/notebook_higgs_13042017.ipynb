# %%
import ROOT as R
# Out:
# Welcome to JupyROOT 6.09/03

# %% [markdown]
# ### Running r-scan for cat6 (01JetsTightBB) on Asimov Dataset w/o freezing any model parameters. pdfindex is on BWZRedux
#
# combine -M MultiDimFit -t -1 --algo=grid --points=200 --rMin=0 --rMax=5 --setPhysicsModelParameters pdfindex_cat6=0,MH=125 --freezeNuisances pdfindex_cat6,MH --expectSignal=1 datacard\_\_cat6\_\_SingleGaus.root -m 125 -S 0 --cminDefaultMinimizerType=Minuit2  --saveWorkspace

# %%
canvas = R.TCanvas("Some Canvas", "Some CAnvas", 800, 600)
f = R.TFile("/afs/cern.ch/work/v/vkhriste/public/Higgs2Mu/datacard_test_12042017_1/higgsCombineTest.MultiDimFit.mH125.root")
t = f.Get("limit")
t.Draw("2*deltaNLL:r","","*")
canvas.Draw()
# Out:
# RooFit v3.60 -- Developed by Wouter Verkerke and David Kirkby
#                 Copyright (C) 2000-2013 NIKHEF, University of California & Stanford University
#                 All rights reserved, please read http://roofit.sourceforge.net/license.txt
# Warning in <TClass::Init>: no dictionary for class RooSpline1D is available
# Warning in <TClass::Init>: no dictionary for class RooMultiPdf is available
# Warning in <TClass::Init>: no dictionary for class RooBernsteinFast<5> is available
# Warning in <TClass::Init>: no dictionary for class ProcessNormalization is available
# Warning in <TClass::Init>: no dictionary for class SimpleGaussianConstraint is available
# Warning in <TClass::Init>: no dictionary for class RooSimultaneousOpt is available

# %% [markdown]
# ### Running r-scan for cat6 on Asimov Dataset w/ freezing a3 parameter for BWZRedux background model.

# %%
f = R.TFile("/afs/cern.ch/work/v/vkhriste/public/Higgs2Mu/datacard_test_12042017_1/higgsCombineTest.MultiDimFit.mH125.root")
t = f.Get("limit")
t.Draw("2*deltaNLL:r","","*")
canvas.Draw()

# %% [markdown]
# ### BWZRedux background model. Running a3_BWZRedux_cat6 scan on Asimov Dataset.
#
# combine -M MultiDimFit -t -1 --algo=grid --points=200 --rMin=0 --rMax=5 --setPhysicsModelParameters pdfindex_cat6=0,MH=125 --freezeNuisances MH,,pdfindex_cat6 --expectSignal=1 datacard__cat6__SingleGaus.root -m 125 -S 0 --cminDefaultMinimizerType=Minuit2 --redefineSignalPOIs a3_BWZRedux_cat6,r -P a3_BWZRedux_cat6 --floatOtherPOIs 1 --saveInactivePOI 1 --robustFit 1 --saveWorkspace

# %%
f = R.TFile("/afs/cern.ch/work/v/vkhriste/public/Higgs2Mu/datacard_test_12042017_1/higgsCombineTest.MultiDimFit.mH125.root")
t = f.Get("limit")
t.Draw("2*deltaNLL:a3_BWZRedux_cat6","","*")
canvas.Draw()

# %% [markdown]
# ### Running r-scan. BWZGamma as background model. Asimov dataset. No freezing of parameters
#
# combine -M MultiDimFit -t -1 --algo=grid --points=200 --rMin=0 --rMax=5 --setPhysicsModelParameters pdfindex_cat6=1,MH=125 --freezeNuisances pdfindex_cat6,MH --expectSignal=1 datacard__cat6__SingleGaus.root -m 125 -S 0 --cminDefaultMinimizerType=Minuit2  --saveWorkspace

# %%
f = R.TFile("/afs/cern.ch/work/v/vkhriste/public/Higgs2Mu/datacard_test_12042017_1/higgsCombineTest.MultiDimFit.mH125.root")
t = f.Get("limit")
t.Draw("2*deltaNLL:r","","*")
canvas.Draw()

# %% [markdown]
# ### Runnign r-scan. BWZGamma. Asimov dataset. Freezing the expParam
#
# combine -M MultiDimFit -t -1 --algo=grid --points=200 --rMin=0 --rMax=5 --setPhysicsModelParameters pdfindex_cat6=1,MH=125 --freezeNuisances pdfindex_cat6,MH,expParam_BWZGamma_cat6 --expectSignal=1 datacard__cat6__SingleGaus.root -m 125 -S 0 --cminDefaultMinimizerType=Minuit2  --saveWorkspace

# %%
f = R.TFile("/afs/cern.ch/work/v/vkhriste/public/Higgs2Mu/datacard_test_13042017_100to150/higgsCombineTest.MultiDimFit.mH125.root")
t = f.Get("limit")
t.Draw("2*deltaNLL:r","","*")
canvas.Draw()

# %% [markdown]
# ### Running Max Likelihood Fit.
#
# combine -M MaxLikelihoodFit -t -1 --rMin=0 --rMax=20000 --setPhysicsModelParameters pdfindex_cat6=1,MH=125 --freezeNuisances pdfindex_cat6,MH,expParam_BWZGamma_cat6 --expectSignal=10 --expectSignalMass=125 datacard__cat6__SingleGaus.root --saveShapes --plots -m 125

# %%
from IPython.display import Image
Image(filename='/afs/cern.ch/work/v/vkhriste/public/Higgs2Mu/datacard_test_13042017_100to150/cat6_x_fit_s.png')

# %%
Image(filename='/afs/cern.ch/work/v/vkhriste/public/Higgs2Mu/datacard_test_13042017_100to150/cat6_x_fit_b.png')

# %%
Image(filename='/afs/cern.ch/work/v/vkhriste/public/Higgs2Mu/datacard_test_13042017/covariance_fit_s.png')

# %%
Image(filename='/afs/cern.ch/work/v/vkhriste/public/Higgs2Mu/datacard_test_13042017/covariance_fit_b.png')

# %% [markdown]
# ### BWZGamma background model. Running expParam_BWZGamma_cat6 scan.
#
# combine -M MultiDimFit -t -1 --algo=grid --points=200 --rMin=0 --rMax=5 --setPhysicsModelParameters pdfindex_cat6=0,MH=125 --freezeNuisances MH,,pdfindex_cat6 --expectSignal=1 datacard__cat6__SingleGaus.root -m 125 -S 0 --cminDefaultMinimizerType=Minuit2 --redefineSignalPOIs a3_BWZRedux_cat6,r -P a3_BWZRedux_cat6 --floatOtherPOIs 1 --saveInactivePOI 1 --robustFit 1 --saveWorkspace

# %%
f = R.TFile("/afs/cern.ch/work/v/vkhriste/public/Higgs2Mu/datacard_test_12042017_1/higgsCombineTest.MultiDimFit.mH125.root")
t = f.Get("limit")
t.Draw("2*deltaNLL:expParam_BWZGamma_cat6","","*")
canvas.Draw()

# %%
f = R.TFile("/afs/cern.ch/work/v/vkhriste/public/Higgs2Mu/datacard_test_12042017_1/higgsCombineTest.MultiDimFit.mH125.root")
t = f.Get("limit")
t.Draw("2*deltaNLL:fraction_BWZGamma_cat6","","*")
canvas.Draw()

# %%
f = R.TFile("/afs/cern.ch/work/v/vkhriste/public/Higgs2Mu/datacard_test_12042017_1/higgsCombineTest.MultiDimFit.mH125.root")
t = f.Get("limit")
t.Draw("2*deltaNLL:b5_BernsteinFast_5_cat6","","*")
canvas.Draw()

# %%
f = R.TFile("/afs/cern.ch/work/v/vkhriste/public/Higgs2Mu/datacard_test_12042017_1/higgsCombineTest.MultiDimFit.mH125.root")
t = f.Get("limit")
t.Draw("2*deltaNLL:b4_BernsteinFast_5_cat6","","*")
canvas.Draw()

# %%
f = R.TFile("/afs/cern.ch/work/v/vkhriste/public/Higgs2Mu/datacard_test_12042017_1/higgsCombineTest.MultiDimFit.mH125.root")
t = f.Get("limit")
t.Draw("2*deltaNLL:b3_BernsteinFast_5_cat6","","*")
canvas.Draw()

# %%
f = R.TFile("/afs/cern.ch/work/v/vkhriste/public/Higgs2Mu/datacard_test_12042017_1/higgsCombineTest.MultiDimFit.mH125.root")
t = f.Get("limit")
t.Draw("2*deltaNLL:b2_BernsteinFast_5_cat6","","*")
canvas.Draw()
